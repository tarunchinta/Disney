# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
names = ['action', 'adventure', 'animation', 'biography', 'crime', 'family', 'fantasy', 'history', 'horror', 'mystery', 'romance', 'scifi', 'sports', 'thriller', 'war']
df = pd.DataFrame() 

for name in names:
    temp_df = pd.read_csv(f'Original Data/{name}.csv')
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.columns
# Out:
# Index(['movie_id', 'movie_name', 'year', 'certificate', 'runtime', 'genre',
#        'rating', 'description', 'director', 'director_id', 'star', 'star_id',
#        'votes', 'gross(in $)'],
#       dtype='object')

# %%
genre_split = df['genre'].str.split(',', expand=True)

df[['Genre1', 'Genre2', 'Genre3']] = genre_split

df[['genre', 'Genre1', 'Genre2', 'Genre3']]
# Out:
#                              genre  Genre1      Genre2    Genre3
# 0         Action, Adventure, Drama  Action   Adventure     Drama
# 1       Action, Adventure, Fantasy  Action   Adventure   Fantasy
# 2                 Action, Thriller  Action    Thriller      None
# 3        Action, Adventure, Comedy  Action   Adventure    Comedy
# 4           Action, Crime, Mystery  Action       Crime   Mystery
# ...                            ...     ...         ...       ...
# 367309         Drama, History, War   Drama     History       War
# 367310                         War     War        None      None
# 367311                         War     War        None      None
# 367312    Action, Adventure, Drama  Action   Adventure     Drama
# 367313                 Comedy, War  Comedy         War      None
#
# [367314 rows x 4 columns]

# %%
print(df.isnull().sum())
# Out:
# movie_id            0
# movie_name          4
# year            53248
# certificate    263145
# runtime        109153
# genre               0
# rating         137360
# description         0
# director        27369
# director_id     27369
# star            58695
# star_id         51858
# votes          137356
# gross(in $)    342313
# Genre1              0
# Genre2          84109
# Genre3         186005
# dtype: int64

# %%
box_office_df = df[df[['gross(in $)', 'runtime', 'director']].notnull().all(axis=1)]

print(box_office_df.isnull().sum(), len(box_office_df))
# Out:
# movie_id          0
# movie_name        0
# year              0
# certificate    1086
# runtime           0
# genre             0
# rating            0
# description       0
# director          0
# director_id       0
# star              7
# star_id           0
# votes             0
# gross(in $)       0
# Genre1            0
# Genre2          249
# Genre3         4276
# dtype: int64 24987

# %%
box_office_df.head()
# Out:
#      movie_id        movie_name  year certificate  runtime  \
# 12  tt1825683     Black Panther  2018       PG-13  134 min
# 14  tt0092099           Top Gun  1986          PG  109 min
# 15  tt0499549            Avatar  2009       PG-13  162 min
# 20  tt1392170  The Hunger Games  2012       PG-13  142 min
# 23  tt1160419              Dune  2021       PG-13  155 min
#
#                          genre  rating  \
# 12   Action, Adventure, Sci-Fi     7.3
# 14               Action, Drama     6.9
# 15  Action, Adventure, Fantasy     7.9
# 20   Action, Adventure, Sci-Fi     7.2
# 23    Action, Adventure, Drama     8.0
#
#                                           description          director  \
# 12  T'Challa, heir to the hidden but advanced king...      Ryan Coogler
# 14  As students at the United States Navy's elite ...        Tony Scott
# 15  A paraplegic Marine dispatched to the moon Pan...     James Cameron
# 20  Katniss Everdeen voluntarily takes her younger...         Gary Ross
# 23  A noble family becomes embroiled in a war for ...  Denis Villeneuve
#
#          director_id                                               star  \
# 12  /name/nm3363032/  Chadwick Boseman, \nMichael B. Jordan, \nLupit...
# 14  /name/nm0001716/  Tom Cruise, \nTim Robbins, \nKelly McGillis, \...
# 15  /name/nm0000116/  Sam Worthington, \nZoe Saldana, \nSigourney We...
# 20  /name/nm0002657/  Jennifer Lawrence, \nJosh Hutcherson, \nLiam H...
# 23  /name/nm0898288/  Timothée Chalamet, \nRebecca Ferguson, \nZenda...
#
#                                               star_id      votes  gross(in $)  \
# 12  /name/nm1569276/,/name/nm0430107/,/name/nm2143...   785813.0  700059566.0
# 14  /name/nm0000129/,/name/nm0000209/,/name/nm0000...   461419.0  179800601.0
# 15  /name/nm0941777/,/name/nm0757855/,/name/nm0000...  1322694.0  760507625.0
# 20  /name/nm2225369/,/name/nm1242688/,/name/nm2955...   927499.0  408010692.0
# 23  /name/nm3154303/,/name/nm0272581/,/name/nm3918...   649342.0  108327830.0
#
#     Genre1      Genre2    Genre3
# 12  Action   Adventure    Sci-Fi
# 14  Action       Drama      None
# 15  Action   Adventure   Fantasy
# 20  Action   Adventure    Sci-Fi
# 23  Action   Adventure     Drama

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://d23.com/list-of-disney-films/'

response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

movie_titles = []
movie_years = []

# Find all <span> tags with the specified font-size, which contain both year and title
spans = soup.find_all('span', style="font-size: 20px;")

for span in spans:
    # Extract text of each span and try to split by '&nbsp;'
    if ':' in span.get_text():
        year = span.get_text().split(':')[0].split()[-1]  # Get year which is last word before ':'
        title_em = span.find('em')  # Find the <em> tag within the span, which contains the title
        if title_em:
            title = title_em.get_text().strip()
            movie_years.append(year)
            movie_titles.append(title)

disney_titles = pd.DataFrame({
    'Year': movie_years,
    'Title': movie_titles
})

print(disney_titles)
# Out:
#      Year                                        Title
# 0    1937              Snow White and the Seven Dwarfs
# 1    1940                                    Pinocchio
# 2    1940                                     Fantasia
# 3    1941                         The Reluctant Dragon
# 4    1941                                        Dumbo
# ..    ...                                          ...
# 760  2022                        Better Nate Than Ever
# 761  2022                                   Polar Bear
# 762  2022  Doctor Strange in the Multiverse of Madness
# 763  2022                                    Pinocchio
# 764  2023                               Chang Can Dunk
#
# [765 rows x 2 columns]

# %%
result_df = pd.merge(box_office_df, disney_titles, left_on=['movie_name', 'year'], right_on=['Title', 'Year'], how='inner')
len(result_df)
# Out:
# 1209

# %%
print(result_df.isnull().sum(), len(result_df))
# Out:
# movie_id        0
# movie_name      0
# year            0
# certificate     6
# runtime         0
# genre           0
# rating          0
# description     0
# director        0
# director_id     0
# star            0
# star_id         0
# votes           0
# gross(in $)     0
# Genre1          0
# Genre2          0
# Genre3         84
# Year            0
# Title           0
# dtype: int64 1209

# %%
cleaned_df = result_df.drop_duplicates()
len(cleaned_df)
# Out:
# 700

# %%
cleaned_df = cleaned_df.drop(columns=['genre', 'Year', 'Title'])
cleaned_df
# Out:
#        movie_id              movie_name  year certificate  runtime  rating  \
# 0     tt1825683           Black Panther  2018       PG-13  134 min     7.3
# 1     tt4154796       Avengers: Endgame  2019       PG-13  181 min     8.4
# 2     tt0478970                 Ant-Man  2015       PG-13  117 min     7.3
# 3     tt9032400                Eternals  2021       PG-13  156 min     6.3
# 4     tt4154756  Avengers: Infinity War  2018       PG-13  149 min     8.4
# ...         ...                     ...   ...         ...      ...     ...
# 1141  tt0140352             The Insider  1999           R  157 min     7.8
# 1174  tt0128278                Instinct  1999           R  126 min     6.5
# 1183  tt0116827              Last Dance  1996           R  103 min     5.7
# 1199  tt0093105   Good Morning, Vietnam  1987           R  121 min     7.3
# 1206  tt0110123         In the Army Now  1994          PG   91 min     4.9
#
#                                             description  \
# 0     T'Challa, heir to the hidden but advanced king...
# 1     After the devastating events of Avengers: Infi...
# 2     Armed with a super-suit with the astonishing a...
# 3     The saga of the Eternals, a race of immortal b...
# 4     The Avengers and their allies must be willing ...
# ...                                                 ...
# 1141  A research chemist comes under personal and pr...
# 1174  When noted anthropologist Dr. Ethan Powell, wh...
# 1183  A lawyer assigned to the clemency case of a wo...
# 1199  In 1965, an unorthodox and irreverent DJ named...
# 1206  Two misguided youths join the reserves to make...
#
#                         director       director_id  \
# 0                   Ryan Coogler  /name/nm3363032/
# 1     Anthony Russo, \nJoe Russo  /name/nm0751577/
# 2                    Peyton Reed  /name/nm0715636/
# 3                     Chloé Zhao  /name/nm2125482/
# 4     Anthony Russo, \nJoe Russo  /name/nm0751577/
# ...                          ...               ...
# 1141                Michael Mann  /name/nm0000520/
# 1174              Jon Turteltaub  /name/nm0005509/
# 1183             Bruce Beresford  /name/nm0000915/
# 1199              Barry Levinson  /name/nm0001469/
# 1206           Daniel Petrie Jr.  /name/nm0677943/
#
#                                                    star  \
# 0     Chadwick Boseman, \nMichael B. Jordan, \nLupit...
# 1     Robert Downey Jr., \nChris Evans, \nMark Ruffa...
# 2     Paul Rudd, \nMichael Douglas, \nCorey Stoll, \...
# 3     Gemma Chan, \nRichard Madden, \nAngelina Jolie...
# 4     Robert Downey Jr., \nChris Hemsworth, \nMark R...
# ...                                                 ...
# 1141  Russell Crowe, \nAl Pacino, \nChristopher Plum...
# 1174  Anthony Hopkins, \nCuba Gooding Jr., \nDonald ...
# 1183  Sharon Stone, \nRob Morrow, \nRandy Quaid, \nP...
# 1199  Robin Williams, \nForest Whitaker, \nTom. T. T...
# 1206  Pauly Shore, \nLori Petty, \nAndy Dick, \nDavi...
#
#                                                 star_id      votes  \
# 0     /name/nm1569276/,/name/nm0430107/,/name/nm2143...   785813.0
# 1     /name/nm0751648/,/name/nm0000375/,/name/nm0262...  1148100.0
# 2     /name/nm0748620/,/name/nm0000140/,/name/nm1015...   675514.0
# 3     /name/nm2110418/,/name/nm0534635/,/name/nm0001...   348052.0
# 4     /name/nm0751648/,/name/nm0000375/,/name/nm1165...  1095301.0
# ...                                                 ...        ...
# 1141  /name/nm0000128/,/name/nm0000199/,/name/nm0001...   173299.0
# 1174  /name/nm0000164/,/name/nm0000421/,/name/nm0000...    33600.0
# 1183  /name/nm0000232/,/name/nm0001555/,/name/nm0001...     4536.0
# 1199  /name/nm0000245/,/name/nm0001845/,/name/nm0870...   144339.0
# 1206  /name/nm0001736/,/name/nm0001614/,/name/nm0004...    14099.0
#
#       gross(in $)     Genre1      Genre2     Genre3
# 0     700059566.0     Action   Adventure     Sci-Fi
# 1     858373000.0     Action   Adventure      Drama
# 2     180202163.0     Action      Comedy     Sci-Fi
# 3     164870234.0     Action   Adventure    Fantasy
# 4     678815482.0     Action   Adventure     Sci-Fi
# ...           ...        ...         ...        ...
# 1141   28965197.0  Biography       Drama   Thriller
# 1174   34098563.0      Drama    Thriller       None
# 1183    5858000.0      Drama    Thriller       None
# 1199  123922370.0  Biography      Comedy      Drama
# 1206   28864707.0     Comedy         War       None
#
# [700 rows x 16 columns]

# %%
cleaned_df.to_csv('disney_movies_cleaned.csv', encoding='utf-8-sig', index=False)
